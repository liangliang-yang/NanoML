# %% [markdown]
# ### Reference
#
# * Chapter 10 `Simulation` in Sheldon Ross
# * https://www.win.tue.nl/~marko/2WB05/lecture8.pdf

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Simulating a geometric distribution from uniform variables

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## `X is integer`

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Simulating a binomial distribution from uniform variables

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ### 关键是上面的 Ui < p, rejection method

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Simulating a Possion distribution from uniform variables

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Uniform (0, 1) to Uniform (a, b)
#
# ![image-2.png](attachment:image-2.png)
